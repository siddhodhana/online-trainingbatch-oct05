# %%
import re
pattern="^[6-9][0-9]{9}$|^[+][9][1][6-9][0-9]{9}$|^[0][6-9][0-9]{9}$"
n=input()
if re.match(pattern,n):
    print("valid")
else:
    print("number not valid")
# Out:
# 987456321099999
# number not valid

# %% [markdown]
# 3 ravi999 @gmail.com
# - username ^[0-9a-zA-Z][a-z0-9._]{5,35}
# - @         [@]
# - domain name [a-z]{4,15}
# - .extension  [.][a-z]{2,4}
#
# pattern="^[0-9a-zA-Z][a-z0-9._]{5,35}[@][a-z]{4,15}[.][a-z]{2,4}$"

# %% [markdown]
# **file**
# - file is a collection data or info
#   .txt,.img,.video,.audio,.exe

# %% [markdown]
# **in python  we have two types of files**
# - text file
# - binary file

# %% [markdown]
# **file handling**
# **CRUD**
# C- creating "x" - write "w"
# R- Reading  "r"
# U - Updating "a"(append)
# D- Deleting

# %%
open(filepath,mode)

# %%
fh=open("ramya.txt")
print(fh)
fh.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-aad4f20f8c47> in <module>
# ----> 1 fh=open("ramya.txt")
#       2 print(fh)
#       3 fh.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ramya.txt'

# %%
fh=open("ramya.txt","w") 
fh.write("write method if file has exist then data has been over written.if file has not existed then write method creates a new file")
fh.close()

# %%
fh=open("ramya.txt","w")
fh.write("data overwritten")
if fh:
    print("create successfully")
else:
    print("no such file here")
fh.close()
# Out:
# create successfully

# %%
fh1=open("abdul.txt","r")
print(fh1.read())
fh1.close()
# Out:
# line1
# line2
# line3
# line4
# line5

# %%
with open("abdul.txt","r") as f:
    print(f.read())
# Out:
# line1
# line2
# line3
# line4
# line5

# %%
with open ("bhavana.txt","a") as f:
    f.write("if file has existed update the data at end of the pointer.if no create new file")

# %%
with open("bhavana.txt","a") as f:
    f.write("\nUpdate the data")

# %%
a="data1\ndata2\ndata3\ndata4\ndata5"
with open("bhavana.txt","a") as f:
    f.write(a)

# %% [markdown]
# **read()**<br>
# **readline()**<br>
# **readlines()**<br>

# %%
with open("bhavana.txt","r") as f:
    print(f.read())
# Out:
# data1
# data2
# data3
# data4
# data5
# data1
# data2
# data3
# data4
# data5

# %%
with open("bhavana.txt","r") as f:
    print(f.readlines())
# Out:
# ['data1\n', 'data2\n', 'data3\n', 'data4\n', 'data5\n', 'data1\n', 'data2\n', 'data3\n', 'data4\n', 'data5']

# %%
with open("bhavana.txt","r") as f:
    for i in range(2,5):
        #i=2,3,4
        #f.seek(5)
        print(f.readline())
# Out:
# data1
#
# data2
#
# data3

# %%
with open("bhavana.txt","r") as f:
    print(f.readline())
# Out:
# data1

# %% [markdown]
# **checking pointer and modifing pointer**
# - tell()
# - seek()

# %%
with open ("bhavana.txt","r") as f:
    print(f.tell())
    f.seek(5)
    print(f.read())
    print(f.tell())
# Out:
# 0
#
# data2
# data3
# data4
# data5
# data1
# data2
# data3
# data4
# data5
# 59

# %%
with open("bhavana.txt","r") as f:
    print(f.read(5))
# Out:
# data1

# %%
import os
os.rename("bhavana.txt","visakha.txt")

# %%
os.mkdir("sagar")

# %%
os.remove("visakha.txt")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\SummerClassesForPython\\Python batch-05'

# %%
os.listdir("e:\movies\\")
# Out:
# ['BA BGC form Version 8- New.pdf',
#  'hindi',
#  'Hollywood',
#  'Praneeth CV 28-08-19.pdf',
#  'Telugu',
#  'www.4MovieRulz.ms_-_V_(2020)_480p_Telugu_Proper_HDRip_x265_DD5.1_950MB_ESub.mkv']

# %%
r+ (first read operation then go write operation)
w+

# %%
with open("abdul.txt","r+") as f:
    print(f.read())
    f.write("\ndata1\ndata2\ndata3\ndata4")
    #print(f.read())
# Out:
# line1
# line2
# line3
# line4
# line5

# %%
with open ("abdul.txt","w+") as f:
    f.write(a)
    f.seek(0)
    print(f.read())
# Out:
# data1
# data2
# data3
# data4
# data5

# %%
a
# Out:
# 'data1\ndata2\ndata3\ndata4\ndata5'

# %%
from random import randint
def marks(n,lb,ub):
    with open("sai.txt","w") as f:
        for i in range(n):
            m=randint(lb,ub)
            f.write(str(m)+"\n")
    return
marks(1000,0,100)

# %%
input.txt=1,2,3,4,5
output.txt=

# %%
with open("abdul.txt","r") as f:
    print(f.read())
# Out:
# data1
# data2
# data3
# data4
# data5

# %%
with open("india1.jpg","r+b") as f:
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x
# ...

# %%
with open("abdul.txt","r+b") as f:
    print(f.read())
# Out:
# b'data1\r\ndata2\r\ndata3\r\ndata4\r\ndata5'

# %%
"x"
"w"
"r"
"a"
"r+"
"w+"
"b"
